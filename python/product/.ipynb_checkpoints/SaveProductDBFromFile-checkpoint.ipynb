# %%
import pandas as pd 
import pymysql 
import csv

# %%
product_data = pd.read_csv('product_data6.csv', engine='python', encoding='UTF-8', error_bad_lines=False, index_col=False)
product_info_data = pd.read_csv('product_info_data6.csv', engine='python', encoding='UTF-8', error_bad_lines=False, index_col=False)
product_image_data = pd.read_csv('product_image_data6.csv', engine='python', encoding='UTF-8', error_bad_lines=False, index_col=False)
# Out:
# C:\Users\seonho\AppData\Local\Temp\ipykernel_47688\3019866018.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   product_data = pd.read_csv('product_data5.csv', engine='python', encoding='UTF-8', error_bad_lines=False, index_col=False)
# C:\Users\seonho\AppData\Local\Temp\ipykernel_47688\3019866018.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   product_info_data = pd.read_csv('product_info_data5.csv', engine='python', encoding='UTF-8', error_bad_lines=False, index_col=False)
# C:\Users\seonho\AppData\Local\Temp\ipykernel_47688\3019866018.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   product_image_data = pd.read_csv('product_image_data5.csv', engine='python', encoding='UTF-8', error_bad_lines=False, index_col=False)

# %%
product_data
# Out:
#     product_no nickname  price                          title
# 0            1        쿤  26000             선물추천♡볼통통한 토끼 볼토 키링
# 1            2        쿤  36000  ⭐️2주소요⭐️ 뜨개 호보백 (blue colors)
# 2            3        쿤   9300                        🍒하트체리키링
# 3            4        쿤  15900   본연의 맛 알맹이만 자몽청 에이드 저칼로리 캠핑 홈
# 4            5        쿤  66000          강남구 서초구 영유 초저 레테 팁 상담
# ..         ...      ...    ...                            ...
# 87          88     건오농장  75000                  탄생석비누 12달 SET
# 88          89     건오농장  86400                     메주-타마누 자운고
# 89          90     건오농장   2900                        오니기리양말🍙
# 90          91     건오농장   3000               바체타팩토리 가죽 안경 케이스
# 91          92     건오농장   8500  네임택 어린이집가방 네임택 유치원 낮잠이불가방 이름표
#
# [92 rows x 4 columns]

# %%
product_info_data
# Out:
#     product_info_no category  \
# 0                 1    핸드메이드
# 1                 2    핸드메이드
# 2                 3    핸드메이드
# 3                 4    핸드메이드
# 4                 5      노하우
# ..              ...      ...
# 87               88    핸드메이드
# 88               89    핸드메이드
# 89               90    핸드메이드
# 90               91    핸드메이드
# 91               92    핸드메이드
#
#                                               content  delivery_fee  \
# 0   귀엽고 앙증맞은\r\n볼 통통한 토끼 "볼토"를 소개합니다.\r\n\r\n오동통한 ...          3000
# 1   👏🏻👏🏻👏🏻\r\n💗2022 상반기 결산 베스트 작품 선정💗\r\n\r\n뜨개 호보...          3000
# 2   🍒 하트 체리 키링\r\n반짝반짝 펄이 들어간 투명 빨간 체리 팬던트에\r\n아크릴...          3000
# 3   ✅️ 리뷰 작성시 ✅️\r\n🎉 청과 어울리는 탄산수 증정!🎉\r\n✨️요청란에 리...          3000
# 4   [서비스 설명]\r\n\r\n1. 전문가 소개\r\n강남에 거주하며 아이를 영어유치...             0
# ..                                                ...           ...
# 87  Birthstone soap 12 SET\r\n60g, 100g\r\n\r\n\r\...          3000
# 88  메주-타마누 자운고\r\nmadagascar TAMANU+자운고\r\n\r\n지치,...          3000
# 89  MAEUM : 마음\r\n\r\n하나하나 예쁘게 정성을 담아 제작하느라\r\n적정량...          3000
# 90  취향에 따라 자유롭게 선택할 수 있도록\r\n20가지 컬러를 준비했습니다.\r\n원...          3000
# 91  아이들 가방, 이불 등에 헷갈리지 않도록\r\n달아주기 좋은 자수 네임텍이예요:)\...          3000
#
#                                           info_notice  \
# 0   종류 | 핸드메이드 손뜨개, 소재 | cotton 55% A/A 45% Wool 5...
# 1     종류 | 호보백/숄더백, 색상\t| Blue 컬러, 소재 | 울 40% 아크릴 60%
# 2   종류 | 키링 악세사리, 소재\t|  태슬 : 샤무드  금속 : 도금, 제조자 / ...
# 3               액상차/서울 중랑구 신내로225 디아뜨갤러리 1층/수령후 5주 이내
# 4                                  연락 가능 시간: 0시 ~ 11시
# ..                                                ...
# 87  보습 클렌징 / 제조일로부터 12개월 / 비누유지,코코넛오일,팜오일,피마자오일,포도...
# 88                     개봉 후 5년 / 서울 종로구 인사동길 36 (관훈동)
# 89  자체제작/대한민국 / 경기 부천시 지봉로63번길 31-16 (역곡동, 삼성하이츠빌)...
# 90  소재: 인조가죽 원산지: 대한민국 제작기간: 영업일 내 1-3일, 최대 7일/ 서울...
# 91                                        면 / 대한민국 /
#
#                    reg_date  stock                 upd_date  view_cnt  \
# 0   2022-12-26 11:59:17.814    100  2022-12-26 11:59:17.814         0
# 1   2022-12-26 12:03:42.763    100  2022-12-26 12:03:42.763         0
# 2   2022-12-26 12:50:57.953      8  2023-01-07 15:18:38.393         0
# 3   2022-12-26 12:55:08.224      6  2023-01-07 15:18:38.357         0
# 4   2022-12-26 13:07:07.810      5  2022-12-26 13:07:07.810         0
# ..                      ...    ...                      ...       ...
# 87  2023-01-20 12:04:54.334     25  2023-01-20 12:05:38.319         4
# 88  2023-01-20 12:10:52.370     20  2023-01-20 12:10:52.370         0
# 89  2023-01-20 13:05:18.384     30  2023-01-20 13:05:18.384         0
# 90  2023-01-20 14:41:02.054     20  2023-01-20 14:41:02.054         0
# 91  2023-01-20 14:47:30.336     20  2023-01-20 14:47:30.336         0
#
#     product_id
# 0            1
# 1            2
# 2            3
# 3            4
# 4            5
# ..         ...
# 87          88
# 88          89
# 89          90
# 90          91
# 91          92
#
# [92 rows x 10 columns]

# %%
product_image_data
# Out:
#      image_id                                        edited_name  \
# 0           1  f0d1e5ab-9293-4087-a8bc-d68a069cfa0cproduct1_1...
# 1           2  fe623db4-41f7-462d-878e-c06bda8efcbeproduct1_2...
# 2           3  1350c1f2-9ad3-4717-83bf-951ecc8f9042product1_3...
# 3           4  1e850bb5-0bf9-4af6-b95d-69d902c3d281product1_4...
# 4           5  01119c6f-b90a-4b6e-aa5a-04a9355d0a73product1_5...
# ..        ...                                                ...
# 558       559  67d6ff00-41ab-4478-92d6-737c01c2cdb9g_handmade...
# 559       560  c8d2a6bf-ccce-4ccf-8fd8-9ceec73b03dfg_handmade...
# 560       561  8b03ec67-ed89-4965-af78-6c3c36347132g_handmade...
# 561       562  2dd176d2-8cae-46f0-bb0b-23de97b069c4g_handmade...
# 562       563  4c620866-57c3-4ffe-aee0-ab8ac171bbd7g_handmade...
#
#                               image_path_flutter  \
# 0    C:\Eddi-T1\flutter\buy_idea\assets\product\
# 1    C:\Eddi-T1\flutter\buy_idea\assets\product\
# 2    C:\Eddi-T1\flutter\buy_idea\assets\product\
# 3    C:\Eddi-T1\flutter\buy_idea\assets\product\
# 4    C:\Eddi-T1\flutter\buy_idea\assets\product\
# ..                                           ...
# 558  C:\Eddi-T1\flutter\buy_idea\assets\product\
# 559  C:\Eddi-T1\flutter\buy_idea\assets\product\
# 560  C:\Eddi-T1\flutter\buy_idea\assets\product\
# 561  C:\Eddi-T1\flutter\buy_idea\assets\product\
# 562  C:\Eddi-T1\flutter\buy_idea\assets\product\
#
#                                      image_path_vue      original_name  \
# 0    C:\Eddi-T1\vue\frontend\src\assets\productImg\     product1_1.jpg
# 1    C:\Eddi-T1\vue\frontend\src\assets\productImg\     product1_2.jpg
# 2    C:\Eddi-T1\vue\frontend\src\assets\productImg\     product1_3.jpg
# 3    C:\Eddi-T1\vue\frontend\src\assets\productImg\     product1_4.jpg
# 4    C:\Eddi-T1\vue\frontend\src\assets\productImg\     product1_5.jpg
# ..                                              ...                ...
# 558  C:\Eddi-T1\vue\frontend\src\assets\productImg\  g_handmade7_1.jpg
# 559  C:\Eddi-T1\vue\frontend\src\assets\productImg\  g_handmade7_2.jpg
# 560  C:\Eddi-T1\vue\frontend\src\assets\productImg\  g_handmade7_3.jpg
# 561  C:\Eddi-T1\vue\frontend\src\assets\productImg\  g_handmade7_4.jpg
# 562  C:\Eddi-T1\vue\frontend\src\assets\productImg\  g_handmade7_5.jpg
#
#      product_id
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 558          92
# 559          92
# 560          92
# 561          92
# 562          92
#
# [563 rows x 6 columns]

# %%
db = pymysql.connect(
    host = 'IP',
    port = 3306,
    user = 'eddi',
    passwd = '비밀번호',
    db = 'buy_idea_db'
)

# %%
f = open('product_data6.csv', 'r', encoding='UTF-8')
csv_reader = csv.reader(f, delimiter=',')

print(csv_reader)

cnt = 0

cursor = db.cursor()

for row in csv_reader:
    if cnt == 0:
        cnt += 1
        continue
    
    nickname = (row[1])
    price = (row[2])
    title = (row[3])

        
    sql = "INSERT INTO product (nickname, price, title) VALUES (%s, %s, %s)"
        
    cursor.execute(sql, (nickname, price, title))

db.commit()

f.close()
# Out:
# <_csv.reader object at 0x000002018DEB0CA0>

# %%
f = open('product_info_data6.csv', 'r', encoding='UTF-8')
csv_reader = csv.reader(f, delimiter=',')

print(csv_reader)


cnt = 0

cursor = db.cursor()

for row in csv_reader:
    if cnt == 0:
        cnt += 1
        continue
    
    category = (row[1])
    content = (row[2])
    delivery_fee = (row[3])
    info_notice = (row[4])
    reg_date = (row[5])
    stock = (row[6])
    upd_date = (row[7])
    view_cnt = (row[8])
    product_id = (row[9])

        
    sql = "INSERT INTO product_info (category, content, delivery_fee, info_notice, reg_date, stock, upd_date, view_cnt, product_id) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"
        
    cursor.execute(sql, (category, content,delivery_fee, info_notice, reg_date, stock, upd_date, view_cnt, product_id))

db.commit()

f.close()
# Out:
# <_csv.reader object at 0x0000020190598A00>

# %%
f = open('product_image_data6.csv', 'r', encoding='UTF-8')
csv_reader = csv.reader(f, delimiter=',')

print(csv_reader)


cnt = 0

cursor = db.cursor()

for row in csv_reader:
    if cnt == 0:
        cnt += 1
        continue
    
    edited_name = (row[1])
    image_path_flutter = (row[2])
    image_path_vue = (row[3])
    original_name = (row[4])
    product_id = (row[5])

        
    sql = "INSERT INTO product_image (edited_name, image_path_flutter, image_path_vue, original_name, product_id) VALUES (%s, %s, %s, %s, %s)"
        
    cursor.execute(sql, (edited_name, image_path_flutter,image_path_vue, original_name, product_id))

db.commit()

f.close()
# Out:
# <_csv.reader object at 0x000002018DEB0F40>

# %%
db.close()

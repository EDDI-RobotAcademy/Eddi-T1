# %%
import pandas as pd 
import pymysql 
import csv

# %%
product_data = pd.read_csv('product_data5.csv', engine='python', encoding='UTF-8', error_bad_lines=False, index_col=False)
product_info_data = pd.read_csv('product_info_data5.csv', engine='python', encoding='UTF-8', error_bad_lines=False, index_col=False)
product_image_data = pd.read_csv('product_image_data5.csv', engine='python', encoding='UTF-8', error_bad_lines=False, index_col=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_80360\2973522227.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   product_data = pd.read_csv('product_data4.csv', engine='python', encoding='UTF-8', error_bad_lines=False, index_col=False)
# C:\Users\user\AppData\Local\Temp\ipykernel_80360\2973522227.py:2: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   product_info_data = pd.read_csv('product_info_data4.csv', engine='python', encoding='UTF-8', error_bad_lines=False, index_col=False)
# C:\Users\user\AppData\Local\Temp\ipykernel_80360\2973522227.py:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   product_image_data = pd.read_csv('product_image_data4.csv', engine='python', encoding='UTF-8', error_bad_lines=False, index_col=False)

# %%
product_data
# Out:
#    product_no nickname  price                          title
# 0          86     건오농장  46800                좁쌀순삭 고체진액팩 기획세트
# 1          87     건오농장  22000    [약산성/피지컨트롤/블랙헤드] 쌀겨효소 파우더워시
# 2          88     건오농장  75000                  탄생석비누 12달 SET
# 3          89     건오농장  86400                     메주-타마누 자운고
# 4          90     건오농장   2900                        오니기리양말🍙
# 5          91     건오농장   3000               바체타팩토리 가죽 안경 케이스
# 6          92     건오농장   8500  네임택 어린이집가방 네임택 유치원 낮잠이불가방 이름표

# %%
product_info_data
# Out:
#    product_info_no category  \
# 0               51    핸드메이드
# 1               52    핸드메이드
# 2               53    핸드메이드
# 3               54    핸드메이드
# 4               55    핸드메이드
# 5               56    핸드메이드
# 6               57    핸드메이드
#
#                                              content  delivery_fee  \
# 0  구성품 : 진액팩145g 2개 + 20g 미니 1개\r\n\r\n몽뜨허브는 10여년...          3000
# 1  슬로우하우스 쌀겨 효소 파우더 워시\r\n\r\n\r\n80g / 약산성클렌져 / ...          3000
# 2  Birthstone soap 12 SET\r\n60g, 100g\r\n\r\n\r\...          3000
# 3  메주-타마누 자운고\r\nmadagascar TAMANU+자운고\r\n\r\n지치,...          3000
# 4  MAEUM : 마음\r\n\r\n하나하나 예쁘게 정성을 담아 제작하느라\r\n적정량...          3000
# 5  취향에 따라 자유롭게 선택할 수 있도록\r\n20가지 컬러를 준비했습니다.\r\n원...          3000
# 6  아이들 가방, 이불 등에 헷갈리지 않도록\r\n달아주기 좋은 자수 네임텍이예요:)\...          3000
#
#                                          info_notice                 reg_date  \
# 0  주식회사 뉴본라이프 / 경기 용인시 기흥구 강남로 9 (구갈동, 태평양프라자) 50...  2023-01-20 11:52:19.407
# 1  서울 용산구 청파로 326 (청파동1가, 고려빌딩) 4층 502호 / 제조일로부터 ...  2023-01-20 12:00:16.206
# 2  보습 클렌징 / 제조일로부터 12개월 / 비누유지,코코넛오일,팜오일,피마자오일,포도...  2023-01-20 12:04:54.334
# 3                     개봉 후 5년 / 서울 종로구 인사동길 36 (관훈동)  2023-01-20 12:10:52.370
# 4  자체제작/대한민국 / 경기 부천시 지봉로63번길 31-16 (역곡동, 삼성하이츠빌)...  2023-01-20 13:05:18.384
# 5  소재: 인조가죽 원산지: 대한민국 제작기간: 영업일 내 1-3일, 최대 7일/ 서울...  2023-01-20 14:41:02.054
# 6                                        면 / 대한민국 /   2023-01-20 14:47:30.336
#
#    stock                 upd_date  view_cnt  product_id
# 0     30  2023-01-20 12:05:21.472         1          86
# 1     30  2023-01-20 12:05:18.739         1          87
# 2     25  2023-01-20 12:05:38.319         4          88
# 3     20  2023-01-20 12:10:52.370         0          89
# 4     30  2023-01-20 13:05:18.384         0          90
# 5     20  2023-01-20 14:41:02.054         0          91
# 6     20  2023-01-20 14:47:30.336         0          92

# %%
product_image_data
# Out:
#     image_id                                        edited_name  \
# 0        528  5d64636d-c5c5-417a-bbff-924304f99a43g_handmade...
# 1        529  60649585-3646-4f53-8e95-1f27aeeddf5ag_handmade...
# 2        530  f1c95914-3f65-4fba-af21-5ea0020463a8g_handmade...
# 3        531  25f2fa41-df7a-47d4-8eb9-0c9c5793f6a3g_handmade...
# 4        532  4c8a7f96-5519-4d11-a01a-a57032ca3b36g_handmade...
# 5        533  4a1b3686-ddc4-45ef-8b21-c089d0b81cccg_handmade...
# 6        534  0c8beae9-a8a8-49d0-9b09-e443035f6507g_handmade...
# 7        535  5df897cb-cbe4-492c-a91e-88600c91cd56g_handmade...
# 8        536  0f60ce4e-df81-4e6a-9105-cf9432542a47g_handmade...
# 9        537  3516aa6b-2a97-4b68-829d-0e43991b11d9g_handmade...
# 10       538  8f8a9e54-737a-4bc7-a78e-3cdddcc418e2g_handmade...
# 11       539  1b02dc75-b60f-4908-884d-b29c61ebc0ebg_handmade...
# 12       540  f1ee88b9-cff2-4481-91bd-56049045737bg_handmade...
# 13       541  a5b0c3f4-7ee1-4cf3-aa75-d53aaa2bb82dg_handmade...
# 14       542  88ccc9f4-dad1-48e0-bace-ea3f9c802ae1g_handmade...
# 15       543  f59dc7d1-a925-44de-83a6-b49f365d388ag_handmade...
# 16       544  3dec357f-60b8-414e-905b-c5f6fea8a443g_handmade...
# 17       545  6cfceaa8-276f-4e9e-ba0f-60a70fb6c924g_handmade...
# 18       546  ccbc0136-3cf9-44f8-abff-881c17aa297cg_handmade...
# 19       547  9b1b0e42-1021-47d0-9bbc-3784f7221fbfg_handmade...
# 20       548  26db3209-a221-4318-af52-49ff70e6eea2g_handmade...
# 21       549  a23798da-5fa9-4eed-b4e2-9e5f394f0fa9g_handmade...
# 22       550  e5889427-6f10-4b53-8632-e3a81a6e954fg_handmade...
C:\Eddi-T1\vue\frontend\src\assets\productImg\  g_handmade6_3.jpg
# 28  C:\Eddi-T1\vue\frontend\src\assets\productImg\  g_handmade6_4.jpg
# 29  C:\Eddi-T1\vue\frontend\src\assets\productImg\  g_handmade6_5.jpg
# 30  C:\Eddi-T1\vue\frontend\src\assets\productImg\  g_handmade6_6.jpg
# 31  C:\Eddi-T1\vue\frontend\src\assets\productImg\  g_handmade7_1.jpg
# 32  C:\Eddi-T1\vue\frontend\src\assets\productImg\  g_handmade7_2.jpg
# 33  C:\Eddi-T1\vue\frontend\src\assets\productImg\  g_handmade7_3.jpg
# 34  C:\Eddi-T1\vue\frontend\src\assets\productImg\  g_handmade7_4.jpg
# 35  C:\Eddi-T1\vue\frontend\src\assets\productImg\  g_handmade7_5.jpg
#
#     product_id
# 0           86
# 1           86
# 2           86
# 3           86
# 4           86
# 5           87
# 6           87
# 7           87
# 8           87
# 9           87
# 10          88
# 11          88
# 12          88
# 13          88
# 14          88
# 15          89
# 16          89
# 17          89
# 18          89
# 19          89
# 20          90
# 21          90
# 22          90
# 23          90
# 24          90
# 25          91
# 26          91
# 27          91
# 28          91
# 29          91
# 30          91
# 31          92
# 32          92
# 33          92
# 34          92
# 35          92

# %%
db = pymysql.connect(
    host = 'IP주소',
    port = 3306,
    user = 'eddi',
    passwd = '비밀번호',
    db = 'buy_idea_db'
)

# %%
f = open('product_data5.csv', 'r', encoding='UTF-8')
csv_reader = csv.reader(f, delimiter=',')

print(csv_reader)

cnt = 0

cursor = db.cursor()

for row in csv_reader:
    if cnt == 0:
        cnt += 1
        continue
    
    nickname = (row[1])
    price = (row[2])
    title = (row[3])

        
    sql = "INSERT INTO product (nickname, price, title) VALUES (%s, %s, %s)"
        
    cursor.execute(sql, (nickname, price, title))

db.commit()

f.close()
# Out:
# <_csv.reader object at 0x00000212F1B4AF40>

# %%
f = open('product_info_data5.csv', 'r', encoding='UTF-8')
csv_reader = csv.reader(f, delimiter=',')

print(csv_reader)


cnt = 0

cursor = db.cursor()

for row in csv_reader:
    if cnt == 0:
        cnt += 1
        continue
    
    category = (row[1])
    content = (row[2])
    delivery_fee = (row[3])
    info_notice = (row[4])
    reg_date = (row[5])
    stock = (row[6])
    upd_date = (row[7])
    view_cnt = 0
    product_id = (row[8])

        
    sql = "INSERT INTO product_info (category, content, delivery_fee, info_notice, reg_date, stock, upd_date, view_cnt, product_id) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)"
        
    cursor.execute(sql, (category, content,delivery_fee, info_notice, reg_date, stock, upd_date, view_cnt, product_id))

db.commit()

f.close()
# Out:
# <_csv.reader object at 0x000001BD89AD8280>

# %%
f = open('product_image_data5.csv', 'r', encoding='UTF-8')
csv_reader = csv.reader(f, delimiter=',')

print(csv_reader)


cnt = 0

cursor = db.cursor()

for row in csv_reader:
    if cnt == 0:
        cnt += 1
        continue
    
    edited_name = (row[1])
    image_path_flutter = (row[2])
    image_path_vue = (row[3])
    original_name = (row[4])
    product_id = (row[5])

        
    sql = "INSERT INTO product_image (edited_name, image_path_flutter, image_path_vue, original_name, product_id) VALUES (%s, %s, %s, %s, %s)"
        
    cursor.execute(sql, (edited_name, image_path_flutter,image_path_vue, original_name, product_id))

db.commit()

f.close()
# Out:
# <_csv.reader object at 0x00000212F1B4AAC0>

# %%
db.close()
